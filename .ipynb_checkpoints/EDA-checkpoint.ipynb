# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading the csv files

# %%
chapters_df = pd.read_csv('Harry_Potter_Movies/Chapters.csv', encoding='ISO-8859-1')
characters_df = pd.read_csv('Harry_Potter_Movies/Characters.csv', encoding='ISO-8859-1')
dialogue_df = pd.read_csv('Harry_Potter_Movies/Dialogue.csv', encoding='ISO-8859-1')
movies_df = pd.read_csv('Harry_Potter_Movies/Movies.csv', encoding='ISO-8859-1')
places_df = pd.read_csv('Harry_Potter_Movies/Places.csv', encoding='ISO-8859-1')
spells_df = pd.read_csv('Harry_Potter_Movies/Spells.csv', encoding='ISO-8859-1')

# %% [markdown]
# ## Combining characters and dialogue to have more detailed analysys

# %%
dialogue_df = dialogue_df.merge(characters_df[['Character ID', 'Character Name', 'Species', 'Gender', 'House']], on='Character ID')
dialogue_df
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               3           1         8             4
# 2               5           1         8             4
# 3               7           1         8             4
# 4               9           1         8             4
# ...           ...         ...       ...           ...
# 7439         7435         234        71            84
# 7440         7437         234        71            84
# 7441         7439         234        71            84
# 7442         7441         234        71            84
# 7443         7444         234        71            84
#
#                                                Dialogue    Character Name  \
# 0     I should have known that you would be here...P...  Albus Dumbledore
# 1      I'm afraid so, Professor. The good, and the bad.  Albus Dumbledore
# 2                               Hagrid is bringing him.  Albus Dumbledore
# 3     Ah, Professor, I would trust Hagrid with my life.  Albus Dumbledore
# 4                         No problems, I trust, Hagrid?  Albus Dumbledore
# ...                                                 ...               ...
# 7439                                               Dad?      Albus Potter
# 7440                      What if I'm put in Slytherin?      Albus Potter
# 7441                               But just say I am --      Albus Potter
# 7442                                            Really?      Albus Potter
# 7443                                             Ready.      Albus Potter
#
#      Species Gender       House
# 0      Human   Male  Gryffindor
# 1      Human   Male  Gryffindor
# 2      Human   Male  Gryffindor
# 3      Human   Male  Gryffindor
# 4      Human   Male  Gryffindor
# ...      ...    ...         ...
# 7439   Human   Male   Slytherin
# 7440   Human   Male   Slytherin
# 7441   Human   Male   Slytherin
# 7442   Human   Male   Slytherin
# 7443   Human   Male   Slytherin
#
# [7444 rows x 9 columns]

# %% [markdown]
# ## Run sentiment analysis over dialogue

# %%
dialogue_df.dtypes
# Out:
# Dialogue ID        int64
# Chapter ID         int64
# Place ID           int64
# Character ID       int64
# Dialogue          object
# Character Name    object
# Species           object
# Gender            object
# House             object
# dtype: object

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
def get_sentiment(text):
    sentiment = analyzer.polarity_scores(str(text))
    return sentiment

# %% [markdown]
# ### Combine dialogue and character name

# %%
dialogue_df['Text'] = dialogue_df[['Dialogue', 'Character Name']].stack().groupby(level=0).agg(' '.join)
dialogue_df['Text'] = dialogue_df['Text'].astype(str)
dialogue_df
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               3           1         8             4
# 2               5           1         8             4
# 3               7           1         8             4
# 4               9           1         8             4
# ...           ...         ...       ...           ...
# 7439         7435         234        71            84
# 7440         7437         234        71            84
# 7441         7439         234        71            84
# 7442         7441         234        71            84
# 7443         7444         234        71            84
#
#                                                Dialogue    Character Name  \
# 0     I should have known that you would be here...P...  Albus Dumbledore
# 1      I'm afraid so, Professor. The good, and the bad.  Albus Dumbledore
# 2                               Hagrid is bringing him.  Albus Dumbledore
# 3     Ah, Professor, I would trust Hagrid with my life.  Albus Dumbledore
# 4                         No problems, I trust, Hagrid?  Albus Dumbledore
# ...                                                 ...               ...
# 7439                                               Dad?      Albus Potter
# 7440                      What if I'm put in Slytherin?      Albus Potter
# 7441                               But just say I am --      Albus Potter
# 7442                                            Really?      Albus Potter
# 7443                                             Ready.      Albus Potter
#
#      Species Gender       House  \
# 0      Human   Male  Gryffindor
# 1      Human   Male  Gryffindor
# 2      Human   Male  Gryffindor
# 3      Human   Male  Gryffindor
# 4      Human   Male  Gryffindor
# ...      ...    ...         ...
# 7439   Human   Male   Slytherin
# 7440   Human   Male   Slytherin
# 7441   Human   Male   Slytherin
# 7442   Human   Male   Slytherin
# 7443   Human   Male   Slytherin
#
#                                                    Text
# 0     I should have known that you would be here...P...
# 1     I'm afraid so, Professor. The good, and the ba...
# 2              Hagrid is bringing him. Albus Dumbledore
# 3     Ah, Professor, I would trust Hagrid with my li...
# 4        No problems, I trust, Hagrid? Albus Dumbledore
# ...                                                 ...
# 7439                                  Dad? Albus Potter
# 7440         What if I'm put in Slytherin? Albus Potter
# 7441                  But just say I am -- Albus Potter
# 7442                               Really? Albus Potter
# 7443                                Ready. Albus Potter
#
# [7444 rows x 10 columns]

# %%
sentiment_df = dialogue_df[['Text', 'Character Name']].copy()
sentiment_df['Sentiment'] = sentiment_df['Text'].apply(get_sentiment)

# %%
sentiment_df['compound'] = sentiment_df['Sentiment'].apply(lambda x: x['compound'])
sentiment_df['positive'] = sentiment_df['compound'].apply(lambda x: 1 if x > 0 else 0)
sentiment_df['negative'] = sentiment_df['compound'].apply(lambda x: 1 if x < 0 else 0)
sentiment_df['neutral'] = sentiment_df['compound'].apply(lambda x: 1 if x == 0 else 0)

# %%
sentiment_by_character = sentiment_df.groupby('Character Name')[['positive', 'negative', 'neutral']].sum()
sentiment_by_character['total'] = sentiment_by_character['positive'] + sentiment_by_character['negative'] + sentiment_by_character['neutral']
sentiment_by_character['total'] = sentiment_by_character['positive'] + sentiment_by_character['negative'] + sentiment_by_character['neutral']
sentiment_by_character['total'] = sentiment_by_character['positive'] + sentiment_by_character['negative'] + sentiment_by_character['neutral']
sentiment_by_character['total'] = sentiment_by_character['positive'] + sentiment_by_character['negative'] + sentiment_by_character['neutral']

sentiment_by_character.sort_values(by='total', ascending=False, inplace=True)
sentiment_by_character[:15]
# Out:
#                     positive  negative  neutral  total
# Character Name
# Harry Potter             457       378     1087   1922
# Ron Weasley              208       211      446    865
# Hermione Granger         223       190      435    848
# Albus Dumbledore         199        98      177    474
# Rubeus Hagrid             79        61       88    228
# Severus Snape             58        33       77    168
# Minerva McGonagall        50        24       56    130
# Horace Slughorn           64        26       38    128
# Voldemort                 36        37       45    118
# Neville Longbottom        26        25       60    111
# Remus Lupin               50        24       36    110
# Draco Malfoy              35        28       40    103
# Alastor Moody             14        77        2     93
# Fred Weasley              29        14       49     92
# Dolores Umbridge          31        21       36     88

# %%
# Set a color palette for the sentiment categories
colors = ['#99ff99', '#ff9999']

# Plot a stacked bar chart for sentiment distribution
ax = sentiment_by_character[:15][['positive', 'negative']].plot(kind='bar', stacked=True, color=colors, figsize=(10, 6), width=0.5)

# Set labels and title
plt.title('Sentiment Analysis for Harry Potter Characters')
plt.xlabel('Character')
plt.ylabel('Number of Sentences')

# Customize legend
legend_labels = ['Positive', 'Negative', 'Neutral']
legend = plt.legend(title='Sentiment', labels=legend_labels, loc='upper right')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show plot
plt.tight_layout()
plt.show()
